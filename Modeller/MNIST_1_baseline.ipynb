# %%
import numpy as np
import keras
import matplotlib.pyplot as plt
# Out:
# 2026-04-14 13:41:35.728574: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776166895.752175   45481 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776166895.759386   45481 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-14 13:41:35.786023: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print("X_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        keras.layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),
        keras.layers.Flatten(),
        keras.layers.Dropout(0.4),
        keras.layers.Dense(10, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 11, 11, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         8,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,578 (68.66 KB)
#  Trainable params: 17,578 (68.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
model.fit(X_train, y_train, batch_size=128, epochs=15, validation_split=0.1)
# Out:
# 2026-04-14 13:42:49.021346: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 169344000 exceeds 10% of free system memory.
# 2026-04-14 13:42:49.702739: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 169344000 exceeds 10% of free system memory.
# Epoch 1/15
# 418/422 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9872 - loss: 0.0396
# 2026-04-14 13:42:52.327008: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_703', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-04-14 13:42:52.344050: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_703', 12 bytes spill stores, 12 bytes spill loads
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9870 - loss: 0.0395 - val_accuracy: 0.9952 - val_loss: 0.0166
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9880 - loss: 0.0372 - val_accuracy: 0.9950 - val_loss: 0.0181
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9880 - loss: 0.0371 - val_accuracy: 0.9937 - val_loss: 0.0192
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9890 - loss: 0.0347 - val_accuracy: 0.9938 - val_loss: 0.0205
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9888 - loss: 0.0341 - val_accuracy: 0.9940 - val_loss: 0.0210
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9893 - loss: 0.0335 - val_accuracy: 0.9935 - val_loss: 0.0206
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9891 - loss: 0.0333 - val_accuracy: 0.9943 - val_loss: 0.0208
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9893 - loss: 0.0336 - val_accuracy: 0.9933 - val_loss: 0.0212
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9894 - loss: 0.0320 - val_accuracy: 0.9933 - val_loss: 0.0222
# Epoch 10/15
# 338/422 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0318
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.fit(X_train, y_train, batch_size=128, epochs=15, validation_split=0.1)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:217, in AtomicFunction.call_preflattened(self, args)
#     215 """Calls with flattened tensor inputs and returns the structured output."""
#     216 flat_outputs = self.call_flat(*args)
# --> 217 return self.function_type.pack_output(flat_outputs)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:446, in FunctionType.pack_output(self, flat_values)
#     444   raise ValueError("Can not pack outputs for undefined output type.")
#     445 else:
# --> 446   return self.output.from_tensors(iter(flat_values))
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:260, in TypeSpec.from_tensors(self, tensors)
#     257 @doc_controls.do_not_doc_inheritable
#     258 def from_tensors(self, tensors):
#     259   """See TraceType base class for details. Do not override."""
# --> 260   components = nest.map_structure(
#     261       lambda spec: spec.from_tensors(tensors),
#     262       self._component_specs
#     263   )
#     264   return self._from_components(components)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/util/nest.py:628, in map_structure(func, *structure, **kwargs)
#     542 @tf_export("nest.map_structure")
#     543 def map_structure(func, *structure, **kwargs):
#     544   """Creates a new structure by applying `func` to each atom in `structure`.
#     545
#     546   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     626     ValueError: If wrong keyword arguments are provided.
#     627   """
# --> 628   return nest_util.map_structure(
#     629       nest_util.Modality.CORE, func, *structure, **kwargs
#     630   )
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:1065, in map_structure(modality, func, *structure, **kwargs)
#     968 """Creates a new structure by applying `func` to each atom in `structure`.
#     969
#     970 - For Modality.CORE: Refer to
#    (...)
#    1062   ValueError: If wrong keyword arguments are provided.
#    1063 """
#    1064 if modality == Modality.CORE:
# -> 1065   return _tf_core_map_structure(func, *structure, **kwargs)
#    1066 elif modality == Modality.DATA:
#    1067   return _tf_data_map_structure(func, *structure, **kwargs)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:1103, in _tf_core_map_structure(func, *structure, **kwargs)
#    1100 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1101 entries = zip(*flat_structure)
# -> 1103 return _tf_core_pack_sequence_as(
#    1104     structure[0],
#    1105     [func(*x) for x in entries],
#    1106     expand_composites=expand_composites,
#    1107 )
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:919, in _tf_core_pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     912   if len(flat_structure) != len(flat_sequence):
#     913     # pylint: disable=raise-missing-from
#     914     raise ValueError(
#     915         "Could not pack sequence. Structure had %d atoms, but "
#     916         "flat_sequence had %d items.  Structure: %s, flat_sequence: %s."
#     917         % (len(flat_structure), len(flat_sequence), structure, flat_sequence)
#     918     )
# --> 919 return sequence_fn(structure, packed)
#
# File ~/hls4ml_proj/venv_HGQ_310/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:244, in sequence_like(instance, args)
#     240 elif isinstance(instance, _wrapt.ObjectProxy):
#     241   # For object proxies, first create the underlying type and then re-wrap it
#     242   # in the proxy type.
#     243   return type(instance)(sequence_like(instance.__wrapped__, args))
# --> 244 elif isinstance(instance, CustomNestProtocol):
#     245   metadata = instance.__tf_flatten__()[0]
#     246   return instance.__tf_unflatten__(metadata, tuple(args))
#
# File /usr/lib/python3.10/typing.py:1503, in _ProtocolMeta.__instancecheck__(cls, instance)
#    1493 if (
#    1494     getattr(cls, '_is_protocol', False) and
#    1495     not getattr(cls, '_is_runtime_protocol', False) and
#    1496     not _allow_reckless_class_checks(depth=2)
#    1497 ):
#    1498     raise TypeError("Instance and class checks can only be used with"
#    1499                     " @runtime_checkable protocols")
#    1501 if ((not getattr(cls, '_is_protocol', False) or
#    1502         _is_callable_members_only(cls)) and
# -> 1503         issubclass(instance.__class__, cls)):
#    1504     return True
#    1505 if cls._is_protocol:
#
# File /usr/lib/python3.10/abc.py:123, in ABCMeta.__subclasscheck__(cls, subclass)
#     121 def __subclasscheck__(cls, subclass):
#     122     """Override for issubclass(subclass, cls)."""
# --> 123     return _abc_subclasscheck(cls, subclass)
#
# KeyboardInterrupt:

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.02808704786002636
# Test accuracy: 0.9912999868392944

# %%
model.save('/home/slopin/DAT255-project/Modeller/mnist_1_baseline.keras')

# %%
import sys
import os

os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tf_keras as keras
sys.modules["tensorflow.keras"] = keras
sys.modules["keras"] = keras

import tensorflow as tf

from tf_keras.models import Sequential
from tf_keras.layers import MaxPooling2D, Activation, Flatten, Dropout
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777292650.760859  187763 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1777292650.761307  187763 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1777292650.803675  187763 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777292651.782202  187763 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1777292651.782549  187763 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
import scipy.io
import numpy as np

def load_svhn(path):
    data = scipy.io.loadmat(path)
    X = data["X"]
    y = data["y"].reshape(-1)

    X = np.transpose(X, (3,0,1,2))

    y[y == 10] = 0

    return X, y

# %%
X_train, y_train = load_svhn("train_32x32.mat")
X_test, y_test   = load_svhn("test_32x32.mat")

X_train = X_train.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0

y_train = keras.utils.to_categorical(y_train, 10)
y_test  = keras.utils.to_categorical(y_test, 10)

# %%
def build_baseline_model():
    model = Sequential()

    model.add(keras.layers.Conv2D(32, (3,3), padding="same", input_shape=(32,32,3)))
    model.add(Activation("relu"))
    model.add(MaxPooling2D())

    model.add(keras.layers.Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(MaxPooling2D())

    model.add(keras.layers.Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(MaxPooling2D())

    model.add(Flatten())

    model.add(keras.layers.Dense(128))
    model.add(Activation("relu"))

    model.add(Dropout(0.5))

    model.add(keras.layers.Dense(10))
    model.add(Activation("softmax"))

    return model

# %%
model = build_baseline_model()

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=20,
    batch_size=128
)
# Out:
# E0000 00:00:1777292662.091719  187763 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1777292662.092206  188214 cuda_executor.cc:1755] Failed to determine cuDNN version (Note that this is expected if the application doesn't link the cuDNN plugin): INTERNAL: cuDNN error: CUDNN_STATUS_INTERNAL_ERROR
# W0000 00:00:1777292662.108945  187763 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/20
# 573/573 [==============================] - 10s 17ms/step - loss: 1.4832 - accuracy: 0.4914 - val_loss: 0.7054 - val_accuracy: 0.8148
# Epoch 2/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.6945 - accuracy: 0.7852 - val_loss: 0.5025 - val_accuracy: 0.8567
# Epoch 3/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.5552 - accuracy: 0.8322 - val_loss: 0.4563 - val_accuracy: 0.8658
# Epoch 4/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.4868 - accuracy: 0.8535 - val_loss: 0.4088 - val_accuracy: 0.8819
# Epoch 5/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.4443 - accuracy: 0.8676 - val_loss: 0.3810 - val_accuracy: 0.8888
# Epoch 6/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.4062 - accuracy: 0.8781 - val_loss: 0.3811 - val_accuracy: 0.8903
# Epoch 7/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.3840 - accuracy: 0.8841 - val_loss: 0.3658 - val_accuracy: 0.8955
# Epoch 8/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.3615 - accuracy: 0.8924 - val_loss: 0.3492 - val_accuracy: 0.9020
# Epoch 9/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.3449 - accuracy: 0.8978 - val_loss: 0.3406 - val_accuracy: 0.9043
# Epoch 10/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.3233 - accuracy: 0.9044 - val_loss: 0.3388 - val_accuracy: 0.9026
# Epoch 11/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.3064 - accuracy: 0.9089 - val_loss: 0.3458 - val_accuracy: 0.9014
# Epoch 12/20
# 573/573 [==============================] - 10s 17ms/step - loss: 0.2947 - accuracy: 0.9116 - val_loss: 0.3440 - val_accuracy: 0.9034
# Epoch 13/20
# 573/573 [==============================] - 10s 17ms/step - loss: 0.2842 - accuracy: 0.9148 - val_loss: 0.3388 - val_accuracy: 0.9083
# Epoch 14/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.2715 - accuracy: 0.9180 - val_loss: 0.3569 - val_accuracy: 0.9024
# Epoch 15/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.2611 - accuracy: 0.9209 - val_loss: 0.3390 - val_accuracy: 0.9089
# Epoch 16/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.2469 - accuracy: 0.9251 - val_loss: 0.3561 - val_accuracy: 0.9110
# Epoch 17/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.2387 - accuracy: 0.9266 - val_loss: 0.3425 - val_accuracy: 0.9105
# Epoch 18/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.2291 - accuracy: 0.9292 - val_loss: 0.3530 - val_accuracy: 0.9108
# Epoch 19/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.2233 - accuracy: 0.9308 - val_loss: 0.3480 - val_accuracy: 0.9121
# Epoch 20/20
# 573/573 [==============================] - 9s 16ms/step - loss: 0.2187 - accuracy: 0.9328 - val_loss: 0.3757 - val_accuracy: 0.9088

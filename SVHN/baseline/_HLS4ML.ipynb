# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import os
import shutil
from sklearn.metrics import accuracy_score
import hls4ml

# %matplotlib inline
seed = 0
np.random.seed(seed)

tf.random.set_seed(seed)

os.environ['PATH'] = os.environ['XILINX_VITIS'] + '/bin:' + os.environ['PATH']

model_name = "SVHN_baseline"

# %%
print(keras.__version__)  
print(hls4ml.__version__)
# Out:
# 3.12.1
# 1.3.0

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_test = X_test.astype("float32") / 255
y_test = keras.utils.to_categorical(y_test, 10)

# %%
from keras.models import load_model
import hgq.layers


model = load_model(f"{model_name}.h5")
score = model.evaluate(X_test, y_test)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ q_conv2d (QConv2D)              │ (None, 26, 26, 16)     │           726 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ q_conv2d_1 (QConv2D)            │ (None, 11, 11, 32)     │        19,186 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 800)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ q_dense (QDense)                │ (None, 10)             │        32,045 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 129,767 (468.68 KB)
#  Trainable params: 38,904 (151.97 KB)
#  Non-trainable params: 13,053 (12.76 KB)
#  Optimizer params: 77,810 (303.95 KB)

# %%
import hls4ml

output_dir = f"hls4ml_prj_{model_name}"

hls_config = hls4ml.utils.config_from_keras_model(model, granularity='name')

#hls_config['Model']['Strategy'] = 'Distributed Arithmetic'
#proj_name = f"{str(model_to_test)}_{str(model_revision)}_hls4ml_prj_{str(hls4ml_revision)}"

hls_model = hls4ml.converters.convert_from_keras_model(
    model,    
    backend='vitis',
    hls_config=hls_config,
    #io_type='io_stream',
    #proj_name = proj_name,
    output_dir=output_dir, 
    board       = 'kv260',
    part='xck26-sfvc784-2LV-c',
    clock_period='5',
)
hls_model.compile()

# %%
hls_model.build(csim=False, synth=True, cosim=False)
# Out:
# ****** vitis-run v2025.2 (64-bit)
#   **** SW Build 6295257 on 2025-11-13-01:29:13
#   **** Start of session at: Thu Apr 30 11:29:08 2026
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
#   **** HLS Build v2025.2 6295257
# Sourcing Tcl script '/home/ncgadmin/DAT255/DAT255-project/MNIST/CNN_HGQ_DynamicTraining/hls4ml_prj_{model_name}/build_prj.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# WARNING: [HLS 200-2182] The 'myproject_prj' project will not automatically appear within Vitis IDE workspaces and is meant only for TCL batch use.  Please use open_component instead of open_project/open_solution to generate Vitis IDE compatible component files and directory structure.
# Resolution: For help on HLS 200-2182 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-2182.html
# INFO: [HLS 200-10] Creating and opening solution '/home/ncgadmin/DAT255/DAT255-project/MNIST/CNN_HGQ_DynamicTraining/hls4ml_prj_{model_name}/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Creating and opening solution '/home/ncgadmin/DAT255/DAT255-project/MNIST/CNN_HGQ_DynamicTraining/hls4ml_prj_{model_name}/myproject_prj/solution1'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see docs.amd.com/access/sources/dita/topic?Doc_Version=2025.2%20English&url=ug1448-hls-guidance&resourceid=200-1505.html
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# ERROR: [HLS 200-101] config_array_partition: Unknown option '-maximum_size'.
# ERROR: [HLS 200-101] config_array_partition: Unknown option '4096'.
# syn.array_partition.complete_threshold=syn.array_partition.throughput_driven=
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xck26-sfvc784-2LV-c
# INFO: [HLS 200-1611] Setting target device to 'xck26-sfvc784-2LV-c'
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: create_clock -period 5 -name default
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 27% default
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 1.35ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 2.21 seconds. CPU system time: 0.09 seconds. Elapsed time: 2.3 seconds; current allocated memory: 243.250 MB.
# INFO: [HLS 200-2191] C-Synthesis will use clang-16 as the compiler
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-7036] unexpected pragma argument 'softmax', expects function/operation (firmware/nnet_utils/nnet_activation.h:402:36)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:33:13)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:107:13)
# WARNING: [HLS 207-6996] 'Resource pragma' is deprecated, use 'bind_op/bind_storage pragma' instead (firmware/nnet_utils/nnet_dense_resource.h:189:13)
# WARNING: [HLS 207-6117] implicit conversion from 'int' to 'signed __attribute__((bitwidth(1)))' changes value from 1 to -1 (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/etc/ap_fixed_base.h:349:21)
# INFO: [HLS 207-5587] in instantiation of member function 'ap_fixed_base<1, 0, true, AP_RND, AP_SAT_SYM>::overflow_adjust' requested here (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/etc/ap_fixed_base.h:909:7)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'ap_fixed_base<1, 0, true, AP_RND, AP_SAT_SYM>::operator=<5, 1, true, AP_TRN, AP_SAT, 0>' requested here (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/etc/ap_fixed_base.h:405:5)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'ap_fixed_base<1, 0, true, AP_RND, AP_SAT_SYM>::ap_fixed_base<5, 1, true, AP_TRN, AP_SAT, 0>' requested here (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/ap_fixed.h:33:9)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'ap_fixed<1, 0, AP_RND, AP_SAT_SYM>::ap_fixed<5, 1, true, AP_TRN, AP_SAT, 0>' requested here (firmware/nnet_utils/nnet_code_gen.h:33:14)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'nnet::q_conv2d_iq<ap_fixed<5, 1, AP_TRN, AP_SAT>, ap_fixed<4, 1>>' requested here (firmware/myproject.cpp:61:11)
# WARNING: [HLS 207-6117] implicit conversion from 'int' to 'signed __attribute__((bitwidth(1)))' changes value from 1 to -1 (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/etc/ap_fixed_base.h:353:21)
# WARNING: [HLS 207-7042] ALLOCATION pragma is ignored, because Instances value is not valid function pointer expression  (firmware/nnet_utils/nnet_pooling.h:180:43)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'nnet::pooling2d_cl<ap_ufixed<8, 4>, ap_ufixed<7, 4>, config5>' requested here (firmware/myproject.cpp:67:11)
# INFO: [HLS 207-5587] in instantiation of member function 'ap_fixed_base<1, -1, true, AP_RND, AP_SAT_SYM>::overflow_adjust' requested here (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/etc/ap_fixed_base.h:909:7)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'ap_fixed_base<1, -1, true, AP_RND, AP_SAT_SYM>::operator=<7, 4, false, AP_TRN, AP_WRAP, 0>' requested here (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/etc/ap_fixed_base.h:405:5)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'ap_fixed_base<1, -1, true, AP_RND, AP_SAT_SYM>::ap_fixed_base<7, 4, false, AP_TRN, AP_WRAP, 0>' requested here (/usr/lib/AMD/2025.2/Vitis/common/technology/autopilot/ap_fixed.h:33:9)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'ap_fixed<1, -1, AP_RND, AP_SAT_SYM>::ap_fixed<7, 4, false, AP_TRN, AP_WRAP, 0>' requested here (firmware/nnet_utils/nnet_code_gen.h:1534:15)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'nnet::q_conv2d_1_iq<ap_ufixed<7, 4>, ap_fixed<3, 1>>' requested here (firmware/myproject.cpp:69:11)
# INFO: [HLS 207-5221] in instantiation of function template specialization 'nnet::pooling2d_cl<ap_ufixed<8, 5>, ap_fixed<3, 2, AP_RND, AP_SAT_SYM>, config9>' requested here (firmware/myproject.cpp:75:11)
# WARNING: [HLS 207-6591] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-6591] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:14:36)
# WARNING: [HLS 207-6591] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:15:36)
# WARNING: [HLS 207-6591] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:16:44)
# WARNING: [HLS 207-6591] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:24:24)
# WARNING: [HLS 207-6591] unused parameter 'buffer' (firmware/nnet_utils/nnet_function_stubs.h:25:24)
# WARNING: [HLS 207-6591] unused parameter 'partition' (firmware/nnet_utils/nnet_function_stubs.h:26:32)
# WARNING: [HLS 207-6591] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:33:30)
# WARNING: [HLS 207-6591] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:33:58)
# WARNING: [HLS 207-6591] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:34:51)
# WARNING: [HLS 207-6591] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:35:49)
# WARNING: [HLS 207-6591] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:42:30)
# WARNING: [HLS 207-6591] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:42:58)
# WARNING: [HLS 207-6591] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:43:51)
# WARNING: [HLS 207-6591] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:44:49)
# WARNING: [HLS 207-6591] unused parameter 'data' (firmware/nnet_utils/nnet_function_stubs.h:51:29)
# WARNING: [HLS 207-6591] unused parameter 'res' (firmware/nnet_utils/nnet_function_stubs.h:51:80)
# WARNING: [HLS 207-6591] unused parameter 'weights' (firmware/nnet_utils/nnet_function_stubs.h:52:50)
# WARNING: [HLS 207-6591] unused parameter 'biases' (firmware/nnet_utils/nnet_function_stubs.h:53:48)
# WARNING: [HLS 207-6591] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:16:39)
# WARNING: [HLS 207-6591] unused parameter 'res' (firmware/nnet_utils/nnet_code_gen.h:17:38)
# WARNING: [HLS 207-6591] unused parameter 'weights' (firmware/nnet_utils/nnet_code_gen.h:18:60)
# WARNING: [HLS 207-6591] unused parameter 'biases' (firmware/nnet_utils/nnet_code_gen.h:19:58)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 15.08 seconds. CPU system time: 0.64 seconds. Elapsed time: 15.72 seconds; current allocated memory: 252.301 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# WARNING: [HLS 200-1995] There were 566,799 instructions in the design after the 'Compile/Link' phase of compilation. See the Design Size Report for more details (/home/ncgadmin/DAT255/DAT255-project/MNIST/CNN_HGQ_DynamicTraining/hls4ml_prj_{model_name}/myproject_prj/solution1/syn/report/csynth_design_size.rpt:2)
